# %%
# import os
# os.environ["DISPLAY"] = ":99"
import vtk
import panel as pn
pn.extension('vtk')

coneSource1 = vtk.vtkConeSource();
mapper = vtk.vtkGlyph3DMapper();
mapper.SetInputConnection(coneSource1.GetOutputPort());
coneSource = vtk.vtkConeSource();
mapper.SetSourceConnection(coneSource.GetOutputPort())
mapper.Update()
actor = vtk.vtkActor();
actor.SetMapper(mapper);


ren = vtk.vtkRenderer()
ren.AddActor(actor)
ren.ResetCamera()


win = vtk.vtkRenderWindow()
win.AddRenderer(ren)


geom_pane = pn.pane.VTK(win, width=500, height=500)
geom_pane
# Out:
# VTKRenderWindowSynchronized(vtkXOpenGLRenderWindow, height=500, sizing_mode='fixed', width=500)

# %%
import os
os.environ
# Out:
# environ{'affinity:container': '=000544bf17e33cfa9ea3f7647ce5b8cf648501ca51e31c51303bb3eca377a6b5',
#         'HOSTNAME': 'bb7c3ce3d2ef',
#         'LANGUAGE': 'C.UTF-8',
#         'PYVISTA_USE_IPYVTK': 'true',
#         'PYMOR_HYPOTHESIS_PROFILE': 'dev',
#         'PWD': '/pymor',
#         'APTINSTALL': 'apt-get install -qq -y --no-install-recommends',
#         'JUPYTER_TOKEN': '666',
#         'CCACHE_DIR': '/tmp/ccache',
#         'OPENBLAS_NUM_THREADS': '1',
#         'HOME': '/home/pymor',
#         'LANG': 'C.UTF-8',
#         'BOOST_VERSION': '1.71.0',
#         'NB_DIR': 'docs/source',
#         'GOTO_NUM_THREADS': '1',
#         'PYMOR_PYTEST_EXTRA': '--lf',
#         'PIP_INSTALL': 'pip install --no-cache-dir -qq',
#         'DOCKER_NGSOLVE': '1',
#         'XDG_CACHE_HOME': '',
#         'PETSC_DIR': '/usr/local/petsc-32',
#         'PYTHONPATH': '/pymor/src:/src/src',
#         'USER': 'rene',
#         'DISPLAY': ':99',
#         'SHLVL': '0',
#         'DOCKER_PYMOR': '1',
#         'MAKE_PROCS': '2',
#         'CI_COMMIT_REF_NAME': 'new_vis',
#         'OMP_NUM_THREADS': '1',
#         'LC_ALL': 'C.UTF-8',
#         'PATH': '/usr/lib/ccache:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#         'PYVISTA_PLOT_THEME': 'document',
#         'DEBIAN_FRONTEND': 'teletype',
#         'PYVISTA_OFF_SCREEN': 'true',
#         '_': '/usr/local/bin/jupyter',
#         'GIT_PYTHON_REFRESH': 'quiet',
#         'JPY_PARENT_PID': '1',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#         'QT_API': 'pyqt5'}
